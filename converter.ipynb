# %%
import numpy as np
import matplotlib.pyplot as plt
from numpy.core.fromnumeric import reshape
import pandas as pd
import datetime
import time
from sklearn import preprocessing

ROWCOUNT = 1
COLUMNCOUNT = 9

name = 'M1'
name2 = 'train'
#datas      = pd.read_csv('/content/drive/Othercomputers/2022 Masaüstü/Dersler 2022/Dersler-2021-2022-Donem-2/Lisans Projesi/EURUSD_'+name+'.csv', header=1)
datas      = pd.read_csv('EURUSD_'+name+'_'+name2+'.csv', header=1)

datas      = datas.values.tolist()
try :
    datas      = np.array([[i.split('\t') for i in k] for k in datas]).reshape(ROWCOUNT,COLUMNCOUNT)
except Exception as e:
    s = str(e).split()
row = int(int(s[5])/COLUMNCOUNT)

datas      = np.array([[i.split('\t') for i in k] for k in datas]).reshape(row,COLUMNCOUNT)

if COLUMNCOUNT ==8 :
    datas_df   = pd.DataFrame(datas,columns=['Date','Open','High','Low','Close','Tickvol','Vol','Spread'])
elif COLUMNCOUNT ==9:
    datas_df   = pd.DataFrame(datas,columns=['Date','Time','Open','High','Low','Close','Tickvol','Vol','Spread'])
datas_df

import dill
dill.dump_session(name+'_'+name2+'-ORJINAL-datas_df.db')

# %%
tmp =0
if 'Time' in datas_df.columns:
    tmp =pd.to_datetime(datas_df['Date']+" "+datas_df['Time'],format='%Y.%m.%d %H:%M:%S')
    datas_df = datas_df.drop('Time',axis=1)
else :
    tmp =pd.to_datetime(datas_df['Date'],format='%Y.%m.%d')
    
#datas_df = datas_df.drop(['Date'],axis=1)
datas_df = datas_df.drop(columns=['Vol'])
datas_df = datas_df.drop(columns=['Tickvol'])
datas_df = datas_df.drop(columns=['Spread'])
tmp
# Out:
# 0         2000-01-03 00:02:00
# 1         2000-01-03 00:04:00
# 2         2000-01-03 00:12:00
# 3         2000-01-03 00:13:00
# 4         2000-01-03 00:14:00
#                   ...
# 7989910   2021-12-30 23:56:00
# 7989911   2021-12-30 23:57:00
# 7989912   2021-12-30 23:58:00
# 7989913   2021-12-30 23:59:00
# 7989914   2021-12-31 00:00:00
# Length: 7989915, dtype: datetime64[ns]

# %%
date2 = pd.DataFrame()
date2['Date'] = tmp
date = tmp
newDate = pd.DatetimeIndex(date)

n2 = pd.DataFrame()
m  = (2 * np.pi * newDate.month/12)
w  = (2 * np.pi * pd.Series(newDate).dt.isocalendar().week/(52.177457))
d  = (2 * np.pi * newDate.day/(365.242199))
h  = (2 * np.pi * newDate.hour/24)
mi = (2 * np.pi * newDate.minute/60)

n2['month_sin']  =  np.round(np.sin(m),5)
n2['month_cos']  =  np.round(np.cos(m),5)
n2['weekly_sin'] =  np.round(np.sin(w),5)
n2['weekly_cos'] =  np.round(np.cos(w),5)
n2['day_sin']   =  np.round(np.sin(d),5)
n2['day_cos']   =  np.round(np.cos(d),5)
n2['hour_sin']  =  np.round(np.sin(h),5)
n2['hour_cos']  =  np.round(np.cos(h),5)
n2['minute_sin'] = np.round(np.sin(mi),5)
n2['minute_cos'] = np.round(np.cos(mi),5)

datas_df = datas_df.drop(columns=['Date'])
#datas_df = datas_df.drop(columns=['Time'])

datas_df = pd.concat([
                      #date2['Date'],
                      datas_df,
                      n2['month_sin'],n2['month_cos'],
                      n2['weekly_sin'],n2['weekly_cos'],
                      n2['day_sin'],n2['day_cos'],
                      n2['hour_sin'],n2['hour_cos'],
                      n2['minute_sin'],n2['minute_cos']
                      ],axis=1)
datas_df
# Out:
#             Open     High      Low    Close  month_sin  month_cos  weekly_sin  \
# 0        1.00790  1.00790  1.00790  1.00790        0.5    0.86603     0.12013
# 1        1.00780  1.00800  1.00770  1.00800        0.5    0.86603     0.12013
# 2        1.00790  1.00790  1.00790  1.00790        0.5    0.86603     0.12013
# 3        1.00800  1.00800  1.00770  1.00770        0.5    0.86603     0.12013
# 4        1.00780  1.00790  1.00760  1.00770        0.5    0.86603     0.12013
# ...          ...      ...      ...      ...        ...        ...         ...
# 7989910  1.13245  1.13253  1.13244  1.13253       -0.0    1.00000    -0.02137
# 7989911  1.13253  1.13254  1.13251  1.13252       -0.0    1.00000    -0.02137
# 7989912  1.13253  1.13253  1.13246  1.13248       -0.0    1.00000    -0.02137
# 7989913  1.13253  1.13257  1.13251  1.13256       -0.0    1.00000    -0.02137
# 7989914  1.13244  1.13244  1.13244  1.13244       -0.0    1.00000    -0.02137
#
#          weekly_cos  day_sin  day_cos  hour_sin  hour_cos  minute_sin  \
# 0           0.99276  0.05159  0.99867   0.00000   1.00000     0.20791
# 1           0.99276  0.05159  0.99867   0.00000   1.00000     0.40674
# 2           0.99276  0.05159  0.99867   0.00000   1.00000     0.95106
# 3           0.99276  0.05159  0.99867   0.00000   1.00000     0.97815
# 4           0.99276  0.05159  0.99867   0.00000   1.00000     0.99452
# ...             ...      ...      ...       ...       ...         ...
# 7989910     0.99977  0.49348  0.86976  -0.25882   0.96593    -0.40674
# 7989911     0.99977  0.49348  0.86976  -0.25882   0.96593    -0.30902
# 7989912     0.99977  0.49348  0.86976  -0.25882   0.96593    -0.20791
# 7989913     0.99977  0.49348  0.86976  -0.25882   0.96593    -0.10453
# 7989914     0.99977  0.50837  0.86114   0.00000   1.00000     0.00000
#
#          minute_cos
# 0           0.97815
# 1           0.91355
# 2           0.30902
# 3           0.20791
# 4           0.10453
# ...             ...
# 7989910     0.91355
# 7989911     0.95106
# 7989912     0.97815
# 7989913     0.99452
# 7989914     1.00000
#
# [7989915 rows x 14 columns]

# %%
np.round(np.sin(w),5)
# Out:
# 0          0.12013
# 1          0.12013
# 2          0.12013
# 3          0.12013
# 4          0.12013
#             ...
# 7989910   -0.02137
# 7989911   -0.02137
# 7989912   -0.02137
# 7989913   -0.02137
# 7989914   -0.02137
# Name: week, Length: 7989915, dtype: Float64

# %%
datas_df.to_csv("EURUSD_"+name+"_hazirVeri_"+name2+"_dongulu.csv", columns =['Open','High','Low','Close',"month_sin","month_cos","weekly_sin","weekly_cos","day_sin","day_cos","hour_sin","hour_cos","minute_sin","minute_cos"])
#datas_df.to_csv("/content/drive/Othercomputers/2022 Masaüstü/Dersler 2022/Dersler-2021-2022-Donem-2/Lisans Projesi/EURUSD_"+name+"_hazirVeri.csv", columns =['Open','High','Low','Close',"month_sin","month_cos","weekly_sin",'weekly_cos','day_sin','day_cos','hour_sin','hour_cos','minute_sin','minute_cos'])
#datas_df.to_csv("EURUSD_"+name+"_hazirVeri_"+name2+".csv", columns =['Date','Open','High','Low','Close'])
