# %%
import numpy as np
import matplotlib.pyplot as plt
from numpy.core.fromnumeric import reshape
import pandas as pd
import datetime
import time
from sklearn import preprocessing

ROWCOUNT = 1
COLUMNCOUNT = 9

name = 'M1'
name2 = 'train'
#datas      = pd.read_csv('/content/drive/Othercomputers/2022 Masaüstü/Dersler 2022/Dersler-2021-2022-Donem-2/Lisans Projesi/EURUSD_'+name+'.csv', header=1)
datas      = pd.read_csv('C:/Users/ertad/Dersler 2022/Dersler-2021-2022-Donem-2/Lisans Github/EURUSD_'+name+'_Feb.csv', header=1)

datas      = datas.values.tolist()
try :
    datas      = np.array([[i.split('\t') for i in k] for k in datas]).reshape(ROWCOUNT,COLUMNCOUNT)
except Exception as e:
    s = str(e).split()
row = int(int(s[5])/COLUMNCOUNT)

datas      = np.array([[i.split('\t') for i in k] for k in datas]).reshape(row,COLUMNCOUNT)

if COLUMNCOUNT ==8 :
    datas_df   = pd.DataFrame(datas,columns=['Date','Open','High','Low','Close','Tickvol','Vol','Spread'])
elif COLUMNCOUNT ==9:
    datas_df   = pd.DataFrame(datas,columns=['Date','Time','Open','High','Low','Close','Tickvol','Vol','Spread'])
datas_df

#import dill
#dill.dump_session(name+'_'+name2+'-ORJINAL-datas_df.db')
# Out:
#              Date      Time     Open     High      Low    Close Tickvol Vol  \
# 0      2022.01.31  00:03:00  1.11389  1.11406  1.11389  1.11406      24   0
# 1      2022.01.31  00:04:00  1.11405  1.11418  1.11405  1.11418      11   0
# 2      2022.01.31  00:05:00  1.11415  1.11455  1.11415  1.11445      20   0
# 3      2022.01.31  00:06:00  1.11451  1.11451  1.11444  1.11448       7   0
# 4      2022.01.31  00:07:00  1.11448  1.11449  1.11442  1.11449      10   0
# ...           ...       ...      ...      ...      ...      ...     ...  ..
# 30196  2022.02.28  23:56:00  1.12193  1.12193  1.12188  1.12189      11   0
# 30197  2022.02.28  23:57:00  1.12189  1.12192  1.12188  1.12190      12   0
# 30198  2022.02.28  23:58:00  1.12190  1.12193  1.12187  1.12190      14   0
# 30199  2022.02.28  23:59:00  1.12189  1.12189  1.12173  1.12178      19   0
# 30200  2022.03.01  00:00:00  1.12177  1.12177  1.12177  1.12177       1   0
#
#       Spread
# 0         78
# 1         55
# 2         38
# 3         38
# 4         23
# ...      ...
# 30196      7
# 30197      7
# 30198      7
# 30199      7
# 30200     46
#
# [30201 rows x 9 columns]

# %%
tmp =0
if 'Time' in datas_df.columns:
    tmp =pd.to_datetime(datas_df['Date']+" "+datas_df['Time'],format='%Y.%m.%d %H:%M:%S')
    datas_df = datas_df.drop('Time',axis=1)
else :
    tmp =pd.to_datetime(datas_df['Date'],format='%Y.%m.%d')
    
#datas_df = datas_df.drop(['Date'],axis=1)
datas_df = datas_df.drop(columns=['Vol'])
datas_df = datas_df.drop(columns=['Tickvol'])
datas_df = datas_df.drop(columns=['Spread'])
tmp
# Out:
# 0       2022-01-31 00:03:00
# 1       2022-01-31 00:04:00
# 2       2022-01-31 00:05:00
# 3       2022-01-31 00:06:00
# 4       2022-01-31 00:07:00
#                 ...
# 30196   2022-02-28 23:56:00
# 30197   2022-02-28 23:57:00
# 30198   2022-02-28 23:58:00
# 30199   2022-02-28 23:59:00
# 30200   2022-03-01 00:00:00
# Length: 30201, dtype: datetime64[ns]

# %%
date2 = pd.DataFrame()
date2['Date'] = tmp
date = tmp
newDate = pd.DatetimeIndex(date)

n2 = pd.DataFrame()
m  = (2 * np.pi * newDate.month/12)
w  = (2 * np.pi * pd.Series(newDate).dt.isocalendar().week/(52.177457))
d  = (2 * np.pi * newDate.day/(365.242199))
h  = (2 * np.pi * newDate.hour/24)
mi = (2 * np.pi * newDate.minute/60)

n2['month_sin']  =  np.round(np.sin(m),5)
n2['month_cos']  =  np.round(np.cos(m),5)
n2['weekly_sin'] =  np.round(np.sin(w),5)
n2['weekly_cos'] =  np.round(np.cos(w),5)
n2['day_sin']   =  np.round(np.sin(d),5)
n2['day_cos']   =  np.round(np.cos(d),5)
n2['hour_sin']  =  np.round(np.sin(h),5)
n2['hour_cos']  =  np.round(np.cos(h),5)
n2['minute_sin'] = np.round(np.sin(mi),5)
n2['minute_cos'] = np.round(np.cos(mi),5)

datas_df = datas_df.drop(columns=['Date'])
#datas_df = datas_df.drop(columns=['Time'])

datas_df = pd.concat([
                      #date2['Date'],
                      datas_df,
                      n2['month_sin'],n2['month_cos'],
                      n2['weekly_sin'],n2['weekly_cos'],
                      n2['day_sin'],n2['day_cos'],
                      n2['hour_sin'],n2['hour_cos'],
                      n2['minute_sin'],n2['minute_cos']
                      ],axis=1)
datas_df
# Out:
#           Open     High      Low    Close  month_sin  month_cos  weekly_sin  \
# 0      1.11389  1.11406  1.11389  1.11406    0.50000    0.86603     0.56637
# 1      1.11405  1.11418  1.11405  1.11418    0.50000    0.86603     0.56637
# 2      1.11415  1.11455  1.11415  1.11445    0.50000    0.86603     0.56637
# 3      1.11451  1.11451  1.11444  1.11448    0.50000    0.86603     0.56637
# 4      1.11448  1.11449  1.11442  1.11449    0.50000    0.86603     0.56637
# ...        ...      ...      ...      ...        ...        ...         ...
# 30196  1.12193  1.12193  1.12188  1.12189    0.86603    0.50000     0.88373
# 30197  1.12189  1.12192  1.12188  1.12190    0.86603    0.50000     0.88373
# 30198  1.12190  1.12193  1.12187  1.12190    0.86603    0.50000     0.88373
# 30199  1.12189  1.12189  1.12173  1.12178    0.86603    0.50000     0.88373
# 30200  1.12177  1.12177  1.12177  1.12177    1.00000    0.00000     0.88373
#
#        weekly_cos  day_sin  day_cos  hour_sin  hour_cos  minute_sin  \
# 0         0.82415  0.50837  0.86114   0.00000   1.00000     0.30902
# 1         0.82415  0.50837  0.86114   0.00000   1.00000     0.40674
# 2         0.82415  0.50837  0.86114   0.00000   1.00000     0.50000
# 3         0.82415  0.50837  0.86114   0.00000   1.00000     0.58779
# 4         0.82415  0.50837  0.86114   0.00000   1.00000     0.66913
# ...           ...      ...      ...       ...       ...         ...
# 30196     0.46799  0.46327  0.88622  -0.25882   0.96593    -0.40674
# 30197     0.46799  0.46327  0.88622  -0.25882   0.96593    -0.30902
# 30198     0.46799  0.46327  0.88622  -0.25882   0.96593    -0.20791
# 30199     0.46799  0.46327  0.88622  -0.25882   0.96593    -0.10453
# 30200     0.46799  0.01720  0.99985   0.00000   1.00000     0.00000
#
#        minute_cos
# 0         0.95106
# 1         0.91355
# 2         0.86603
# 3         0.80902
# 4         0.74314
# ...           ...
# 30196     0.91355
# 30197     0.95106
# 30198     0.97815
# 30199     0.99452
# 30200     1.00000
#
# [30201 rows x 14 columns]

# %%
np.round(np.sin(w),5)
# Out:
# 0        0.56637
# 1        0.56637
# 2        0.56637
# 3        0.56637
# 4        0.56637
#           ...
# 30196    0.88373
# 30197    0.88373
# 30198    0.88373
# 30199    0.88373
# 30200    0.88373
# Name: week, Length: 30201, dtype: Float64

# %%
datas_df.to_csv("C:/Users/ertad/Dersler 2022/Dersler-2021-2022-Donem-2/Lisans Github/EURUSD_"+name+"_hazirVeri_"+name2+"_Feb_dongulu.csv", columns =['Open','High','Low','Close',"month_sin","month_cos","weekly_sin","weekly_cos","day_sin","day_cos","hour_sin","hour_cos","minute_sin","minute_cos"])
#datas_df.to_csv("/content/drive/Othercomputers/2022 Masaüstü/Dersler 2022/Dersler-2021-2022-Donem-2/Lisans Projesi/EURUSD_"+name+"_hazirVeri.csv", columns =['Open','High','Low','Close',"month_sin","month_cos","weekly_sin",'weekly_cos','day_sin','day_cos','hour_sin','hour_cos','minute_sin','minute_cos'])
#datas_df.to_csv("EURUSD_"+name+"_hazirVeri_"+name2+".csv", columns =['Date','Open','High','Low','Close'])
