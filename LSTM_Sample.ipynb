# %%
from numpy import array
from numpy import hstack
from keras.models import Sequential
from keras.layers import LSTM
from keras.layers import Dense
import matplotlib.pyplot as plt
from pandas import read_csv
import math
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split
import pandas as pd
import numpy as np
from keras.layers.core import Dense, Activation, Dropout
from datetime import datetime
import time
from keras.activations import *
scaler  = MinMaxScaler(feature_range=(0, 1))
model = Sequential()
X_train =0
y_train =0
X_test =0
y_test =0
name ="M1"
df_train = read_csv('EURUSD_'+name+'_hazirVeri_train.csv', engine='python')
df_train   = pd.DataFrame(df_train.values,columns=["Index","Date","Open","High","Low","Close"])
df_train
# Out:
#            Index                 Date     Open     High      Low    Close
# 0              0  2000-01-03 00:02:00   1.0079   1.0079   1.0079   1.0079
# 1              1  2000-01-03 00:04:00   1.0078    1.008   1.0077    1.008
# 2              2  2000-01-03 00:12:00   1.0079   1.0079   1.0079   1.0079
# 3              3  2000-01-03 00:13:00    1.008    1.008   1.0077   1.0077
# 4              4  2000-01-03 00:14:00   1.0078   1.0079   1.0076   1.0077
# ...          ...                  ...      ...      ...      ...      ...
# 7989910  7989910  2021-12-30 23:56:00  1.13245  1.13253  1.13244  1.13253
# 7989911  7989911  2021-12-30 23:57:00  1.13253  1.13254  1.13251  1.13252
# 7989912  7989912  2021-12-30 23:58:00  1.13253  1.13253  1.13246  1.13248
# 7989913  7989913  2021-12-30 23:59:00  1.13253  1.13257  1.13251  1.13256
# 7989914  7989914  2021-12-31 00:00:00  1.13244  1.13244  1.13244  1.13244
#
# [7989915 rows x 6 columns]

# %%
df_train['Date'] = pd.to_datetime(df_train['Date'],format= '%Y-%m-%d %H:%M:%S')

# %%
df_train['Date'].astype('float32')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_16268/3345508681.py in <module>
# ----> 1 df_train['Date'].astype('float32')
#
# ~\miniconda3\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5813         else:
#    5814             # else, only a single dtype is given
# -> 5815             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5816             return self._constructor(new_data).__finalize__(self, method="astype")
#    5817
#
# ~\miniconda3\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, copy, errors)
#     416
#     417     def astype(self: T, dtype, copy: bool = False, errors: str = "raise") -> T:
# --> 418         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     419
#     420     def convert(
#
# ~\miniconda3\lib\site-packages\pandas\core\internals\managers.py in apply(self, f, align_keys, ignore_failures, **kwargs)
#     325                     applied = b.apply(f, **kwargs)
#     326                 else:
# --> 327                     applied = getattr(b, f)(**kwargs)
#     328             except (TypeError, NotImplementedError):
#     329                 if not ignore_failures:
#
# ~\miniconda3\lib\site-packages\pandas\core\internals\blocks.py in astype(self, dtype, copy, errors)
#     589         values = self.values
#     590
# --> 591         new_values = astype_array_safe(values, dtype, copy=copy, errors=errors)
#     592
#     593         new_values = maybe_coerce_values(new_values)
#
# ~\miniconda3\lib\site-packages\pandas\core\dtypes\cast.py in astype_array_safe(values, dtype, copy, errors)
#    1307
#    1308     try:
# -> 1309         new_values = astype_array(values, dtype, copy=copy)
#    1310     except (ValueError, TypeError):
#    1311         # e.g. astype_nansafe can fail on object-dtype of strings
#
# ~\miniconda3\lib\site-packages\pandas\core\dtypes\cast.py in astype_array(values, dtype, copy)
#    1252     if not isinstance(values, np.ndarray):
#    1253         # i.e. ExtensionArray
# -> 1254         values = values.astype(dtype, copy=copy)
#    1255
#    1256     else:
#
# ~\miniconda3\lib\site-packages\pandas\core\arrays\datetimes.py in astype(self, dtype, copy)
#     644         elif is_period_dtype(dtype):
#     645             return self.to_period(freq=dtype.freq)
# --> 646         return dtl.DatetimeLikeArrayMixin.astype(self, dtype, copy)
#     647
#     648     # -----------------------------------------------------------------
#
# ~\miniconda3\lib\site-packages\pandas\core\arrays\datetimelike.py in astype(self, dtype, copy)
#     422             # and conversions for any datetimelike to float
#     423             msg = f"Cannot cast {type(self).__name__} to dtype {dtype}"
# --> 424             raise TypeError(msg)
#     425         elif is_categorical_dtype(dtype):
#     426             arr_cls = dtype.construct_array_type()
#
# TypeError: Cannot cast DatetimeArray to dtype float32

# %%
from keras.models import Model
from keras.layers import Input
from keras.layers import LSTM
from numpy import array
# define model
inputs1 = Input(shape=(3, 1))
lstm1 = LSTM(1)(inputs1)
model = Model(inputs=inputs1, outputs=lstm1)
# define input data
data = array([0.1, 0.2, 0.3]).reshape((1,3,1))
# make and show prediction
print(model.predict(data))
